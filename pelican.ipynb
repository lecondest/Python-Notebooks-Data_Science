# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('PelicanStores_Data.csv')

# %%
# %matplotlib inline

# %%
0df.head(3)
# Out:
#    Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 0         1          Regular      1       39.5          Discover    Male
# 1         2      Promotional      1      102.4  Proprietary Card  Female
# 2         3          Regular      1       22.5  Proprietary Card  Female
#
#   Marital Status  Age
# 0        Married   32
# 1        Married   36
# 2        Married   32

# %%
df['net_sales'] = pd.qcut(df['Net Sales'],4,labels=['<40','<60','<100','>100'])

# %%
df.head()
# Out:
#    Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 0         1          Regular      1       39.5          Discover    Male
# 1         2      Promotional      1      102.4  Proprietary Card  Female
# 2         3          Regular      1       22.5  Proprietary Card  Female
# 3         4      Promotional      5      100.4  Proprietary Card  Female
# 4         5          Regular      2       54.0        MasterCard  Female
#
#   Marital Status  Age net_sales
# 0        Married   32       <40
# 1        Married   36      >100
# 2        Married   32       <40
# 3        Married   28      <100
# 4        Married   34       <60

# %%
fdf.groupby('net_sales').plot()
# Out:
# net_sales
# <40     AxesSubplot(0.125,0.125;0.775x0.755)
# <60     AxesSubplot(0.125,0.125;0.775x0.755)
# <100    AxesSubplot(0.125,0.125;0.775x0.755)
# >100    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df.net_sales.value_counts(sort=False)
# Out:
# <40     26
# <60     24
# <100    25
# >100    25
# Name: net_sales, dtype: int64
